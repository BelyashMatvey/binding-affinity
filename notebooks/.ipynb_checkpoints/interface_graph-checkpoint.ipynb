# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))

from binding_affinity.utils.visualization import PlotlyVis
from binding_affinity.data.dataset import AtomicGraphDataset

# %%
dataset = AtomicGraphDataset(Path("../data/affinity_test.json"), graph_radius=4.0, n_neighbors=8, bipartite=False)
interface_graph = dataset[4]
interface_graph
# Out:
# Data(edge_index=[2, 2996], atoms=[366], residues=[366], is_receptor=[366], coordinates=[366, 3], distances=[2996], num_nodes=366, affinity=-11.758866764673641)

# %%
PlotlyVis.create_figure(interface_graph)
